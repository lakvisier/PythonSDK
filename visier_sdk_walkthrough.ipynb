# %% [markdown]
# # Visier Python SDK - Interactive Walkthrough
#
# This notebook provides a step-by-step guide to using the Visier Python SDK to query employee data.
#
# ## Learning Objectives
#
# By the end of this walkthrough, you will understand how to:
# - Configure the Visier Python SDK
# - Authenticate with Visier Platform
# - Build and execute data queries
# - Process and analyze query results
#
# ## Prerequisites
#
# - Python 3.9 or higher
# - Visier Platform account with API access
# - API credentials configured in `.env` file

# %% [markdown]
# ## Step 1: Setup and Imports
#
# First, let's import the necessary libraries and set up our environment.

# %%
import sys
import warnings
from datetime import datetime
import os

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore', message='.*urllib3.*NotOpenSSLWarning.*')
warnings.filterwarnings('ignore', message='.*urllib3 v2 only supports OpenSSL.*')

# Load environment variables from .env file
try:
    from dotenv import load_dotenv
    load_dotenv()
    print('✅ Loaded environment variables from .env file')
except ImportError:
    print('⚠️ python-dotenv not installed. Using system environment variables.')

# Import Visier SDK components
from visier_platform_sdk import ApiClient, Configuration, DataQueryApi
from visier_platform_sdk.models import ListQueryExecutionDTO
from visier_platform_sdk.exceptions import ServiceException, ApiException, BadRequestException, UnauthorizedException, ApiValueError

import pandas as pd

print('✅ All imports successful!')
# Out:
# ✅ Loaded environment variables from .env file
# ✅ All imports successful!

# %% [markdown]
# ## Step 2: Verify Configuration
#
# Let's check that all required environment variables are set.

# %%
# Check required environment variables
required_vars = [
    'VISIER_HOST',
    'VISIER_APIKEY',
    'VISIER_VANITY',
    'VISIER_USERNAME',
    'VISIER_PASSWORD'
]

missing_vars = [var for var in required_vars if not os.getenv(var)]

if missing_vars:
    print('❌ Missing required environment variables:')
    for var in missing_vars:
        print(f'   - {var}')
    print('\nPlease set these in your .env file or environment.')
    print('See visier.env.example for a template.')
else:
    print('✅ All required environment variables are set!')
    print(f"   Host: {os.getenv('VISIER_HOST')}")
    print(f"   Vanity: {os.getenv('VISIER_VANITY')}")
    print(f"   Username: {os.getenv('VISIER_USERNAME')}")
# Out:
# ✅ All required environment variables are set!
#    Host: https://css9xazus3demo7.api.visier.io
#    Vanity: css9xazus3demo7
#    Username: laktest

# %% [markdown]
# ## Step 3: Create Configuration
#
# The `Configuration` object holds all your Visier API credentials. The SDK can automatically read these from environment variables using `Configuration.from_env()`.
#
# **What this does:**
# - Reads VISIER_HOST, VISIER_APIKEY, VISIER_VANITY from environment
# - Reads VISIER_USERNAME and VISIER_PASSWORD for basic authentication
# - Creates a configuration object ready to use

# %%
# Create configuration from environment variables
config = Configuration.from_env()

# Set as default configuration (optional, but recommended)
Configuration.set_default(config)

print('✅ Configuration created successfully!')
print(f'   Host: {config.host}')
print(f'   Vanity: {config.vanity}')
print(f'   API Key: {"*" * 20} (hidden)')
print(f'   Username: {config.username}')
# Out:
# ✅ Configuration created successfully!
#    Host: https://css9xazus3demo7.api.visier.io
#    Vanity: css9xazus3demo7
#    API Key: ******************** (hidden)
#    Username: laktest

# %% [markdown]
# ## Step 4: Create API Client
#
# The `ApiClient` is your connection to the Visier API. It handles:
# - Automatic authentication (happens on first API call)
# - Request formatting
# - Response parsing
# - Token management
#
# **Key Point:** Authentication happens automatically when you make your first API call. You don't need to manually authenticate!

# %%
# Create the API client
api_client = ApiClient(config)

print('✅ API client created!')
print('   (Authentication will happen automatically on first API call)')
# Out:
# ✅ API client created!
#    (Authentication will happen automatically on first API call)

# %% [markdown]
# ## Step 5: Create Data Query API
#
# The `DataQueryApi` provides methods to query data from Visier. The main methods are:
# - `list()`: Execute a list query (returns detailed records)
# - `aggregate()`: Execute an aggregation query (returns summaries)
# - `snapshot()`: Execute a snapshot query (time series data)
#
# We'll use `list()` to get detailed employee records.

# %%
# Create DataQueryApi instance
data_query_api = DataQueryApi(api_client)

print('✅ DataQueryApi ready!')
# Out:
# ✅ DataQueryApi ready!

# %% [markdown]
# ## Step 6: Build the Query
#
# A query defines what data you want to retrieve. It has several components:
#
# 1. **Source**: Which analytic object to query (e.g., 'Employee')
# 2. **Columns**: Which properties to retrieve
# 3. **Time Interval**: What time period to query
# 4. **Options**: Pagination, limits, etc.
#
# Let's build a query for employee data with three properties:
# - EmployeeID
# - Time_in_Role
# - Span_Of_Control

# %%
# Define the query as a dictionary
# This is easier to read and modify than building DTOs directly
query_dict = {
    'source': {'analyticObject': 'Employee'},
    'columns': [
        {
            'columnName': 'Employee ID',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.EmployeeID',
                    'qualifyingPath': 'Employee'
                }
            }
        },
        {
            'columnName': 'Time in Role',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.Time_in_Role',
                    'qualifyingPath': 'Employee'
                }
            }
        },
        {
            'columnName': 'Span of Control',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.Span_Of_Control',
                    'qualifyingPath': 'Employee'
                }
            }
        }
    ],
    'timeInterval': {'fromInstant': '1735689600000'},  # December 1, 2024
    'options': {'limit': 10000, 'page': 0}
}

# Use from_dict() to create DTO directly from dictionary (simpler than from_json)
query_dto = ListQueryExecutionDTO.from_dict(query_dict)

print('✅ Query built successfully!')
print(f"   Analytic Object: {query_dict['source']['analyticObject']}")
print(f"   Properties: {len(query_dict['columns'])} columns")
print(f"   Time Period: From December 1, 2024")
print(f"   Limit: {query_dict['options']['limit']} records")
# Out:
# ✅ Query built successfully!
#    Analytic Object: Employee
#    Properties: 3 columns
#    Time Period: From December 1, 2024
#    Limit: 10000 records

# %% [markdown]
# ## Step 7: Execute the Query
#
# Now we'll send the query to Visier and retrieve the data. The SDK handles all the HTTP communication, authentication, and response parsing for us.
#
# **What happens:**
# 1. SDK sends the query to Visier API
# 2. Authentication happens automatically (if not already authenticated)
# 3. Visier processes the query
# 4. Response is returned as a `ListResponse` object

# %%
# Execute the query
print('🔧 Executing query...')
print('   (This may take a few seconds...)')

response = data_query_api.list(query_dto)

print('✅ Query executed successfully!')
print(f'   Response type: {type(response).__name__}')

if hasattr(response, 'rows') and response.rows:
    print(f'   Records returned: {len(response.rows)}')
else:
    print('   No rows in response')
# Out:
# 🔧 Executing query...
#    (This may take a few seconds...)
# ✅ Query executed successfully!
#    Response type: ListResponse
#    Records returned: 4136

# %% [markdown]
# ## Step 8: Process the Response
#
# The response comes back in a structured format with numeric keys. We need to:
# 1. Extract the header (column names)
# 2. Extract the rows (data)
# 3. Map numeric keys to column names
# 4. Convert to a pandas DataFrame for easier analysis
#
# **Response Structure:**
# ```python
# {
#     'header': {'0': 'Employee ID', '1': 'Time in Role', '2': 'Span of Control'},
#     'rows': [
#         {'0': 'Employee-123', '1': 22, '2': 0},
#         ...
#     ]
# }
# ```

# %%
# Convert response to dictionary if needed
if hasattr(response, 'to_dict'):
    data = response.to_dict()
elif hasattr(response, '__dict__'):
    data = {}
    if hasattr(response, 'header'):
        data['header'] = response.header
    if hasattr(response, 'rows'):
        data['rows'] = response.rows
else:
    data = response

# Extract header and rows
header = data.get('header', {})
rows = data.get('rows', [])

print(f'✅ Extracted {len(rows)} rows with {len(header)} columns')
print(f"   Column names: {list(header.values())[:3]}...")
# Out:
# ✅ Extracted 4136 rows with 3 columns
#    Column names: ['Employee ID', 'Time in Role', 'Span of Control']...
# /Users/lakshman.rajanathan/Cursor/PythonSDK/.venv/lib/python3.14/site-packages/pydantic/main.py:464: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee ID', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Time in Role', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Span of Control', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6872', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1299', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=2, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2665', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6360', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=8, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5589', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=14, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3680', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3066', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-159', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=5, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2319', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5691', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-69', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6609', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=3, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3763', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=45, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5345', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=19, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=2, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1323', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2933', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-10', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=10, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1055', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-261', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4247', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=31, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4003', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=37, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4861', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=24, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4759', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=25, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6526', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=5, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6175', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2748', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=2, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6687', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6258', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5101', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=23, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6955', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-773', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=16, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6014', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-344', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=31, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=5, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-690', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=25, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-856', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-427', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=18, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5857', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-100', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=7, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1138', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=7, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3417', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3334', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4515', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=27, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=4, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2153', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1996', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6443', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=7, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-11', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=2, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5692', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4945', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=24, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4516', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=27, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=3, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5960', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2749', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6688', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3681', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2154', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=41, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-613', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5429', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=17, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2934', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=2, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3579', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1056', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6200', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=6, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6956', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5858', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4677', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=25, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6444', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=7, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1997', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-7030', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2851', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6790', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1670', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4701', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=25, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5078', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=23, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4862', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=23, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6176', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2666', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=4, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2237', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6873', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3603', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3335', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4594', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=26, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5102', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=23, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6712', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1407', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6259', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3764', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=45, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2422', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3067', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1241', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=24, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=3, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2398', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=20, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-101', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=10, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3252', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-530', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=31, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1753', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1485', input_type=str])
# ...
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5159', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=23, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=6, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1917', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=6, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2235', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-509', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=6, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6174', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4592', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=26, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4080', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=24, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-68', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4246', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=35, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6442', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=7, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2932', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4943', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=24, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6608', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=3, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5939', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1483', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=20, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=4, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2152', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=12, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3333', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=10, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6871', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-1649', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=4, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2747', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-7009', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2396', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-5690', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=13, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3762', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=45, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6091', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6686', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6525', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=5, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-3065', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-6257', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=11, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-4758', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=25, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=1, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value='Employee-2420', input_type=str])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=47, input_type=int])
#   PydanticSerializationUnexpectedValue(Expected `Any` - serialized value may not be as expected [field_name='additional_properties', input_value=0, input_type=int])
#   return self.__pydantic_serializer__.to_python(

# %%
# Create mapping from numeric keys to column names
column_mapping = {
    str(k): header[str(k)] 
    for k in sorted([int(k) for k in header.keys()])
}

# Convert rows to list of dictionaries with proper column names
df_rows = []
for row in rows:
    df_row = {
        column_mapping.get(str(k), k): row.get(str(k))
        for k in sorted([int(k) for k in row.keys()])
    }
    df_rows.append(df_row)

# Create DataFrame
df = pd.DataFrame(df_rows)

# Reorder columns to match original header order
column_order = [
    column_mapping[str(k)]
    for k in sorted([int(k) for k in header.keys()])
]
df = df[column_order]

print('✅ Data converted to DataFrame!')
print(f'   Shape: {df.shape[0]} rows, {df.shape[1]} columns')
print(f'   Columns: {list(df.columns)}')
# Out:
# ✅ Data converted to DataFrame!
#    Shape: 4136 rows, 3 columns
#    Columns: ['Employee ID', 'Time in Role', 'Span of Control']

# %% [markdown]
# ## Step 9: Display Results
#
# Now let's view the data we retrieved!

# %%
# Display first 20 rows
print('=' * 70)
print('Query Results')
print('=' * 70)
print(f'\nFound {len(df)} employee record(s):\n')

display(df.head(20))
# Out:
# ======================================================================
# Query Results
# ======================================================================
#
# Found 4136 employee record(s):
#       Employee ID  Time in Role  Span of Control
# 0   Employee-6872             0                0
# 1   Employee-1299            47                2
# 2   Employee-2665            47                0
# 3   Employee-6360             8                0
# 4   Employee-5589            14                0
# 5   Employee-3680            47                0
# 6   Employee-3066            47                1
# 7    Employee-159            47                5
# 8   Employee-2319            47                0
# 9   Employee-5691            13                0
# 10    Employee-69            47               12
# 11  Employee-6609             3                0
# 12  Employee-3763            45                0
# 13  Employee-5345            19                2
# 14  Employee-1323             1                1
# 15  Employee-2933            13                0
# 16    Employee-10            47               10
# 17  Employee-1055            13                0
# 18   Employee-261            47                1
# 19  Employee-4247            31                0

# %% [markdown]
# ## Step 10: Basic Analysis
#
# Now that we have the data, let's do some basic analysis!

# %%
# Basic statistics
print('📊 Basic Statistics:')
print('=' * 70)

if 'Time in Role' in df.columns:
    print(f'\nTime in Role:')
    print(f'   Mean: {df["Time in Role"].mean():.1f} months')
    print(f'   Median: {df["Time in Role"].median():.1f} months')
    print(f'   Min: {df["Time in Role"].min()} months')
    print(f'   Max: {df["Time in Role"].max()} months')

if 'Span of Control' in df.columns:
    print(f'\nSpan of Control:')
    print(f'   Mean: {df["Span of Control"].mean():.1f} direct reports')
    print(f'   Employees with direct reports: {(df["Span of Control"] > 0).sum()}')
    print(f'   Employees with 10+ direct reports: {(df["Span of Control"] >= 10).sum()}')
# Out:
# 📊 Basic Statistics:
# ======================================================================
#
# Time in Role:
#    Mean: 24.4 months
#    Median: 22.0 months
#    Min: 0 months
#    Max: 47 months
#
# Span of Control:
#    Mean: 1.0 direct reports
#    Employees with direct reports: 1312
#    Employees with 10+ direct reports: 71

# %% [markdown]
# ## Summary and Next Steps
#
# ### What We Learned
#
# 1. **Configuration**: Use `Configuration.from_env()` to load credentials from environment variables
# 2. **API Client**: The `ApiClient` handles authentication automatically
# 3. **Query Structure**: Queries define source, columns, time period, and options
# 4. **Execution**: Use `DataQueryApi.list()` to execute list queries
# 5. **Processing**: Convert responses to DataFrames for easier analysis
#
# ### Next Steps
#
# - Try modifying the query to get different properties
# - Experiment with different time periods
# - Explore other API methods (`aggregate()`, `snapshot()`)
# - Add filters to the query
# - Export data to CSV or Excel
#
# ### Resources
#
# - [Visier Python SDK Documentation](https://github.com/visier/python-sdk)
# - [Visier API Reference](https://documentation.visier.com/)
# - [Visier API Samples](https://github.com/visier/api-samples)

# %%
# Optional: Save to CSV
# df.to_csv('employee_data.csv', index=False)
# print('✅ Data saved to employee_data.csv')
