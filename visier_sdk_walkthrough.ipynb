# %% [markdown]
# # Visier Python SDK - Interactive Walkthrough
#
# This notebook provides a step-by-step guide to using the Visier Python SDK to query employee data.
#
# ## Learning Objectives
#
# By the end of this walkthrough, you will understand how to:
# - Configure the Visier Python SDK
# - Authenticate with Visier Platform
# - Build and execute data queries
# - Process and analyze query results
#
# ## Prerequisites
#
# - Python 3.9 or higher
# - Visier Platform account with API access
# - API credentials configured in `.env` file

# %% [markdown]
# ## Step 1: Setup and Imports
#
# First, let's import the necessary libraries and set up our environment.

# %%
import sys
import warnings
import json
from datetime import datetime
import os

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore', message='.*urllib3.*NotOpenSSLWarning.*')
warnings.filterwarnings('ignore', message='.*urllib3 v2 only supports OpenSSL.*')

# Load environment variables from .env file
try:
    from dotenv import load_dotenv
    load_dotenv()
    print('✅ Loaded environment variables from .env file')
except ImportError:
    print('⚠️ python-dotenv not installed. Using system environment variables.')

# Import Visier SDK components
from visier_platform_sdk import ApiClient, Configuration, DataQueryApi
from visier_platform_sdk.models import ListQueryExecutionDTO
from visier_platform_sdk.exceptions import ServiceException, ApiException, BadRequestException, UnauthorizedException, ApiValueError

import pandas as pd

print('✅ All imports successful!')
# Out:
# ✅ Loaded environment variables from .env file
# ✅ All imports successful!

# %% [markdown]
# ## Step 2: Verify Configuration
#
# Let's check that all required environment variables are set.

# %%
# Check required environment variables
required_vars = [
    'VISIER_HOST',
    'VISIER_APIKEY',
    'VISIER_VANITY',
    'VISIER_USERNAME',
    'VISIER_PASSWORD'
]

missing_vars = [var for var in required_vars if not os.getenv(var)]

if missing_vars:
    print('❌ Missing required environment variables:')
    for var in missing_vars:
        print(f'   - {var}')
    print('\nPlease set these in your .env file or environment.')
    print('See visier.env.example for a template.')
else:
    print('✅ All required environment variables are set!')
    print(f"   Host: {os.getenv('VISIER_HOST')}")
    print(f"   Vanity: {os.getenv('VISIER_VANITY')}")
    print(f"   Username: {os.getenv('VISIER_USERNAME')}")
# Out:
# ✅ All required environment variables are set!
#    Host: https://css9xazus3demo7.api.visier.io
#    Vanity: css9xazus3demo7
#    Username: laktest

# %% [markdown]
# ## Step 3: Create Configuration
#
# The `Configuration` object holds all your Visier API credentials. The SDK can automatically read these from environment variables using `Configuration.from_env()`.
#
# **What this does:**
# - Reads VISIER_HOST, VISIER_APIKEY, VISIER_VANITY from environment
# - Reads VISIER_USERNAME and VISIER_PASSWORD for basic authentication
# - Creates a configuration object ready to use

# %%
# Create configuration from environment variables
config = Configuration.from_env()

# Set as default configuration (optional, but recommended)
Configuration.set_default(config)

print('✅ Configuration created successfully!')
print(f'   Host: {config.host}')
print(f'   Vanity: {config.vanity}')
print(f'   API Key: {"*" * 20} (hidden)')
print(f'   Username: {config.username}')
# Out:
# ✅ Configuration created successfully!
#    Host: https://css9xazus3demo7.api.visier.io
#    Vanity: css9xazus3demo7
#    API Key: ******************** (hidden)
#    Username: laktest

# %% [markdown]
# ## Step 4: Create API Client
#
# The `ApiClient` is your connection to the Visier API. It handles:
# - Automatic authentication (happens on first API call)
# - Request formatting
# - Response parsing
# - Token management
#
# **Key Point:** Authentication happens automatically when you make your first API call. You don't need to manually authenticate!

# %%
# Create the API client
api_client = ApiClient(config)

print('✅ API client created!')
print('   (Authentication will happen automatically on first API call)')
# Out:
# ✅ API client created!
#    (Authentication will happen automatically on first API call)

# %% [markdown]
# ## Step 5: Create Data Query API
#
# The `DataQueryApi` provides methods to query data from Visier. The main methods are:
# - `list()`: Execute a list query (returns detailed records)
# - `aggregate()`: Execute an aggregation query (returns summaries)
# - `snapshot()`: Execute a snapshot query (time series data)
#
# We'll use `list()` to get detailed employee records.

# %%
# Create DataQueryApi instance
data_query_api = DataQueryApi(api_client)

print('✅ DataQueryApi ready!')
# Out:
# ✅ DataQueryApi ready!

# %% [markdown]
# ## Step 6: Build the Query
#
# A query defines what data you want to retrieve. It has several components:
#
# 1. **Source**: Which analytic object to query (e.g., 'Employee')
# 2. **Columns**: Which properties to retrieve
# 3. **Time Interval**: What time period to query
# 4. **Options**: Pagination, limits, etc.
#
# Let's build a query for employee data with three properties:
# - EmployeeID
# - Time_in_Role
# - Span_Of_Control

# %%
# Define the query as a dictionary
# This is easier to read and modify than building DTOs directly
query_dict = {
    'source': {'analyticObject': 'Employee'},
    'columns': [
        {
            'columnName': 'Employee ID',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.EmployeeID',
                    'qualifyingPath': 'Employee'
                }
            }
        },
        {
            'columnName': 'Time in Role',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.Time_in_Role',
                    'qualifyingPath': 'Employee'
                }
            }
        },
        {
            'columnName': 'Span of Control',
            'columnDefinition': {
                'property': {
                    'name': 'Employee.Span_Of_Control',
                    'qualifyingPath': 'Employee'
                }
            }
        }
    ],
    'timeInterval': {'fromInstant': '1735689600000'},  # December 1, 2024
    'options': {'limit': 10000, 'page': 0}
}

# Convert dictionary to JSON string, then create DTO
json_string = json.dumps(query_dict)
query_dto = ListQueryExecutionDTO.from_json(json_string)

print('✅ Query built successfully!')
print(f"   Analytic Object: {query_dict['source']['analyticObject']}")
print(f"   Properties: {len(query_dict['columns'])} columns")
print(f"   Time Period: From December 1, 2024")
print(f"   Limit: {query_dict['options']['limit']} records")
# Out:
# ✅ Query built successfully!
#    Analytic Object: Employee
#    Properties: 3 columns
#    Time Period: From December 1, 2024
#    Limit: 10000 records

# %% [markdown]
# ## Step 7: Execute the Query
#
# Now we'll send the query to Visier and retrieve the data. The SDK handles all the HTTP communication, authentication, and response parsing for us.
#
# **What happens:**
# 1. SDK sends the query to Visier API
# 2. Authentication happens automatically (if not already authenticated)
# 3. Visier processes the query
# 4. Response is returned as a `ListResponse` object

# %%
# Execute the query
print('🔧 Executing query...')
print('   (This may take a few seconds...)')

response = data_query_api.list(query_dto)

print('✅ Query executed successfully!')
print(f'   Response type: {type(response).__name__}')

if hasattr(response, 'rows') and response.rows:
    print(f'   Records returned: {len(response.rows)}')
else:
    print('   No rows in response')
# Out:
# 🔧 Executing query...
#    (This may take a few seconds...)
# ✅ Query executed successfully!
#    Response type: ListResponse
#    Records returned: 4349

# %% [markdown]
# ## Step 8: Process the Response
#
# The response comes back in a structured format with numeric keys. We need to:
# 1. Extract the header (column names)
# 2. Extract the rows (data)
# 3. Map numeric keys to column names
# 4. Convert to a pandas DataFrame for easier analysis
#
# **Response Structure:**
# ```python
# {
#     'header': {'0': 'Employee ID', '1': 'Time in Role', '2': 'Span of Control'},
#     'rows': [
#         {'0': 'Employee-123', '1': 22, '2': 0},
#         ...
#     ]
# }
# ```

# %%
# Convert response to dictionary if needed
if hasattr(response, 'to_dict'):
    data = response.to_dict()
elif hasattr(response, '__dict__'):
    data = {}
    if hasattr(response, 'header'):
        data['header'] = response.header
    if hasattr(response, 'rows'):
        data['rows'] = response.rows
else:
    data = response

# Extract header and rows
header = data.get('header', {})
rows = data.get('rows', [])

print(f'✅ Extracted {len(rows)} rows with {len(header)} columns')
print(f"   Column names: {list(header.values())[:3]}...")
# Out:
# ✅ Extracted 4349 rows with 3 columns
#    Column names: ['Employee ID', 'Time in Role', 'Span of Control']...
# /Users/lakshman.rajanathan/Desktop/Cursor/PythonSDK/venv/lib/python3.8/site-packages/pydantic/main.py:426: UserWarning: Pydantic serializer warnings:
#   Expected `Any` but got `str` with value `'Employee ID'` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Time in Role'` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Span of Control'` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6034'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6566'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7350'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1211'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `37` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-92'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1743'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5383'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7217'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3563'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2562'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5068'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `34` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4746'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `36` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1099'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7385'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5747'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6384'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4711'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `36` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5712'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3031'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6069'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `21` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2597'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `34` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5530'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `25` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4214'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2779'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `40` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `8` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4249'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `42` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-586'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7567'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2212'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `36` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7000'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7035'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `9` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3213'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `46` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4599'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `8` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-201'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5880'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4928'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3745'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6531'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3381'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `16` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-551'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1778'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1561'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7714'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1064'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7532'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7036'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `9` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3564'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2745'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6714'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-587'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1562'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5748'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7568'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-419'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-93'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6217'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1030'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3599'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2213'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5384'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1247'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-370'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2248'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2563'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7351'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4565'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `37` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-202'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7218'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6567'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7001'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3249'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7386'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4712'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `31` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `6` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-552'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6350'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `14` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1926'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7715'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6385'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3382'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4068'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5566'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3746'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `19` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2927'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5034'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3214'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `20` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5881'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6532'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1597'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7533'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-769'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6749'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2381'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6883'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3215'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7219'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7170'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3712'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7534'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2382'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `53` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `6` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-94'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `8` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6533'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5532'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `25` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2599'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-203'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4384'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `37` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7569'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7037'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `9` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2746'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `16` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2928'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7002'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1598'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7387'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1213'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5035'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4881'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7716'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5882'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-238'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `9` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5567'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-917'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2214'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5749'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4069'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `46` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3565'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-735'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4566'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6036'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-700'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `15` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3033'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `30` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3929'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `48` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2249'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5350'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2564'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6386'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-588'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7352'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4532'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `37` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5386'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7535'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2880'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `6` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7171'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2712'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `15` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4350'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `38` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2530'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6534'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7500'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4217'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `43` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4749'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5533'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6884'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-204'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-701'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6170'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `18` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'p_Employee-1'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-589'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1711'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-60'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-918'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5001'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7388'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1032'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3069'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7003'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-95'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3384'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `7` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3216'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6002'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2747'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5351'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7717'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3713'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `54` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
# ...
#   Expected `Any` but got `str` with value `'Employee-4597'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `36` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `5` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4380'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `38` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3596'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2595'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `6` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1608'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6711'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1923'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6214'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7383'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3561'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4926'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5927'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1244'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7566'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6068'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `21` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3597'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6215'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `17` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-550'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4031'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `47` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2064'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-732'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `29` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2561'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3429'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `21` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1777'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7034'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `9` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `2` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4598'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6383'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7713'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5928'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `23` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6530'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7216'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3030'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `3` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1609'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `32` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2099'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6747'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7069'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `8` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3562'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2596'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `27` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `8` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3744'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `24` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6712'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `12` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6565'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `13` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7384'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `1` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-949'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5382'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `26` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1595'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `35` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6880'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-3926'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `48` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `7` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6929'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `11` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-91'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `10` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1924'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-7531'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-2925'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `4` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-6033'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `22` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `6` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-5564'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `25` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-4248'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `42` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `7` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-417'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `50` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   Expected `Any` but got `str` with value `'Employee-1245'` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `59` - serialized value may not be as expected
#   Expected `Any` but got `int` with value `0` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_python(

# %%
# Create mapping from numeric keys to column names
column_mapping = {
    str(k): header[str(k)] 
    for k in sorted([int(k) for k in header.keys()])
}

# Convert rows to list of dictionaries with proper column names
df_rows = []
for row in rows:
    df_row = {
        column_mapping.get(str(k), k): row.get(str(k))
        for k in sorted([int(k) for k in row.keys()])
    }
    df_rows.append(df_row)

# Create DataFrame
df = pd.DataFrame(df_rows)

# Reorder columns to match original header order
column_order = [
    column_mapping[str(k)]
    for k in sorted([int(k) for k in header.keys()])
]
df = df[column_order]

print('✅ Data converted to DataFrame!')
print(f'   Shape: {df.shape[0]} rows, {df.shape[1]} columns')
print(f'   Columns: {list(df.columns)}')
# Out:
# ✅ Data converted to DataFrame!
#    Shape: 4349 rows, 3 columns
#    Columns: ['Employee ID', 'Time in Role', 'Span of Control']

# %% [markdown]
# ## Step 9: Display Results
#
# Now let's view the data we retrieved!

# %%
# Display first 20 rows
print('=' * 70)
print('Query Results')
print('=' * 70)
print(f'\nFound {len(df)} employee record(s):\n')

display(df.head(20))
# Out:
# ======================================================================
# Query Results
# ======================================================================
#
# Found 4349 employee record(s):
#       Employee ID  Time in Role  Span of Control
# 0   Employee-6034            22                0
# 1   Employee-6566            13                0
# 2   Employee-7350             1                0
# 3   Employee-1211            37                0
# 4     Employee-92            59               10
# 5   Employee-1743            59                0
# 6   Employee-5383            26                0
# 7   Employee-7217             4                0
# 8   Employee-3563            59                0
# 9   Employee-2562            22                2
# 10  Employee-5068            34                3
# 11  Employee-4746            36                1
# 12  Employee-1099            59                1
# 13  Employee-7385             1                0
# 14  Employee-5747            24                2
# 15  Employee-6384            13                0
# 16  Employee-4711            36                0
# 17  Employee-5712            24                0
# 18  Employee-3031            59                0
# 19  Employee-6069            21                0

# %% [markdown]
# ## Step 10: Basic Analysis
#
# Now that we have the data, let's do some basic analysis!

# %%
# Basic statistics
print('📊 Basic Statistics:')
print('=' * 70)

if 'Time in Role' in df.columns:
    print(f'\nTime in Role:')
    print(f'   Mean: {df["Time in Role"].mean():.1f} months')
    print(f'   Median: {df["Time in Role"].median():.1f} months')
    print(f'   Min: {df["Time in Role"].min()} months')
    print(f'   Max: {df["Time in Role"].max()} months')

if 'Span of Control' in df.columns:
    print(f'\nSpan of Control:')
    print(f'   Mean: {df["Span of Control"].mean():.1f} direct reports')
    print(f'   Employees with direct reports: {(df["Span of Control"] > 0).sum()}')
    print(f'   Employees with 10+ direct reports: {(df["Span of Control"] >= 10).sum()}')
# Out:
# 📊 Basic Statistics:
# ======================================================================
#
# Time in Role:
#    Mean: 27.2 months
#    Median: 23.0 months
#    Min: 0 months
#    Max: 59 months
#
# Span of Control:
#    Mean: 1.0 direct reports
#    Employees with direct reports: 1379
#    Employees with 10+ direct reports: 85

# %% [markdown]
# ## Summary and Next Steps
#
# ### What We Learned
#
# 1. **Configuration**: Use `Configuration.from_env()` to load credentials from environment variables
# 2. **API Client**: The `ApiClient` handles authentication automatically
# 3. **Query Structure**: Queries define source, columns, time period, and options
# 4. **Execution**: Use `DataQueryApi.list()` to execute list queries
# 5. **Processing**: Convert responses to DataFrames for easier analysis
#
# ### Next Steps
#
# - Try modifying the query to get different properties
# - Experiment with different time periods
# - Explore other API methods (`aggregate()`, `snapshot()`)
# - Add filters to the query
# - Export data to CSV or Excel
#
# ### Resources
#
# - [Visier Python SDK Documentation](https://github.com/visier/python-sdk)
# - [Visier API Reference](https://documentation.visier.com/)
# - [Visier API Samples](https://github.com/visier/api-samples)

# %%
# Optional: Save to CSV
# df.to_csv('employee_data.csv', index=False)
# print('✅ Data saved to employee_data.csv')
